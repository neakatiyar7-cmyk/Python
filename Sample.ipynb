# %%
_name ='Ram'

print(_name)
# Out:
# Ram

# %%
_name
# Out:
# 'Ram'

# %%
type(_name)
# Out:
# str

# %%
type('Ram')
# Out:
# str

# %%
City = "Pune"

City
# Out:
# 'Pune'

# %%
per = 7.8
per
# Out:
# 7.8

# %%
type(per)
# Out:
# float

# %%
city  # not defined above
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 city  # not defined above
#
# NameError: name 'city' is not defined

# %%
5num=10

# %%
roll num = 11

# %%
num5 = 100

num5

# %%
type(num5)

# %%
roll_num =11

roll_num

# %%
type(roll_num)

# %%
if =7

# %%
@city = "MH"

# %%
import keyword

# %%
keyword .kwlist  # Stores all the keywords in the list

# %%
len(keyword.kwlist)  # gives the length of the list

# %%
stmt  = ' I am from 
Maharashtra '

# %%
stmt  = ''' I am from 
Maharashtra '''

# %%
stmt    # Added the newline in the output

# %%
res = True

# %%
type(res)

# %%
num = 5 +7j

# %%
type(num)

# %%
n = input ("Enter any number")

# %%
input ("Enter any number")

# %%
type(n)

# %%
n1 = input ("Enter any number")

# %%
n+n1

# %%
print(type(n))

# %%
b = int (n)
type(b)

# %%
b

# %%
c = '5.7'

d = float(c)

type(d)

# %%
c = '5.7'

d = int(c)

type(d)   # invalid casting

# %%
xx ='5.8'

d = int(float(xx))

type(d)

# %%
int(True)

# %%
int(False)

# %%
float(True)

# %%
float(False)   # case sensitive
# Out:
# 0.0

# %%
n5 = int(input ("Enter number"))
# Out:
# Enter number 7

# %%
n5
# Out:
# 7

# %%
type(n5)
# Out:
# int

# %%
print("Pune")
print("MH")
# Out:
# Pune
# MH

# %%
print("Pune", end =",")    # end ="," used to end the newline character in print 
print("MH")
# Out:
# Pune,MH

# %%
print("Number is :" , n5)
# Out:
# Number is : 7

# %%
print( f"{n5} is new number")
# Out:
# 7 is new number

# %%
print( "{n5} is new number")  # considers it as normal string
# Out:
# {n5} is new number

# %%
num1 = int(input("Enter number"))    #addition of a number 
num2 = int(input("Enter number"))
add = num1 +num2
# Out:
# Enter number 3
# Enter number 4

# %%
print("Addition of 2 numbers is:" , add)
# Out:
# Addition of 2 numbers is: 7

# %%
print(f" Addition of {num1} and {num2} is {add}")
# Out:
#  Addition of 3 and 4 is 7

# %%
print(f" Addition of {type(num1)} and {type(num2)} is {add}")
# Out:
#  Addition of <class 'int'> and <class 'int'> is 7

# %%
num3 = int(input("Enter number"))    #Subtraction of a number
num4 = int(input("Enter number"))
sub = num3 -num4
print(f" Subtraction of {num3} and {num4} is {sub}")
# Out:
# Enter number 5
# Enter number 4
#  Subtraction of 5 and 4 is 1

# %%
num5 = int(input("Enter number"))     # multiplication of a number 
num6 = int(input("Enter number"))
mul = num5*num6
print(f" Multiplication of {num5} and {num6} is {mul}")
# Out:
# Enter number 2
# Enter number 3
#  Multiplication of 2 and 3 is 6

# %%
num7 = int(input("Enter number"))      # division of a number
num8 = int(input("Enter number"))
div = num7 /num8
print(f" Division of {num7} and {num8} is {div}")
# Out:
# Enter number 10
# Enter number 2
#  Division of 10 and 2 is 5.0

# %%
num9 = int(input("Enter number"))       # division of a number 
num10 = int(input("Enter number"))
res = num9 //num10
print(f" Result of {num9} and {num10} is {res}")
# Out:
# Enter number 10
# Enter number 2
#  Result of 10 and 2 is 5

# %%
num11 = int(input("Enter number"))       # remainder of a number 
num12 = int(input("Enter number"))
res1 = num11 %num12
print(f" Result of {num11} and {num12} is {res1}")
# Out:
# Enter number 10
# Enter number 2
#  Result of 10 and 2 is 0

# %%
num13 = int(input("Enter number"))        #cube of a number
num14 = int(input("Enter number"))
res2 = num13**num14
print(f" Result of {num13} and {num14} is {res2}")
# Out:
# Enter number 2
# Enter number 3
#  Result of 2 and 3 is 8

# %%
import math                          # square root of a number 
num15 = int(input("Enter number"))
root  = math.sqrt(num15)
print(f" SQUARE root  of {num15}  is {root}")
# Out:
# Enter number 4
#  SQUARE root  of 4  is 2.0

# %%
num16 = int(input("Enter number"))
root  = num16** (1/2)
print(f" SQUARE root  of {num16}  is {root}")
# Out:
# Enter number 4
#  SQUARE root  of 4  is 2.0

# %%
num17 = int(input("Enter the radius of the circle"))
area = 3.14 *(num17)*(num17)
print(f" Area   of circle of radius {num17}  is {area }")
# Out:
# Enter the radius of the circle 2
#  Area   of circle of radius 2  is 12.56

# %%
h = int(input("Enter the height of the triangle"))
b = int(input("Enter the base of the triangle"))
areatri = 0.5 *(h)*(b)
print(f" Area   of circle of radius is {areatri }")
# Out:
# Enter the height of the triangle 2
# Enter the base of the triangle 3
#  Area   of circle of radius is 3.0
